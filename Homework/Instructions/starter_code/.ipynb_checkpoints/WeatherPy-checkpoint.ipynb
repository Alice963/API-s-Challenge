# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 592

# %%
# Base URL to work off                         
base_url = "http://api.openweathermap.org/data/2.5/weather?"

# Counter to go through data
record = 0
sets = 1

# Create DataFrame
weather_df = pd.DataFrame({"City": cities})

weather_df["Country"] = ""
weather_df["Date"] = ""      
weather_df["Latitude"] = ""
weather_df["Longitude"] = ""
weather_df["Cloudiness (%)"] = ""
weather_df["Humidity (%)"] = ""
weather_df["Max Temp (F)"] = ""
weather_df["Wind Speed (mph)"] = ""


# Interate through Cities and retrieve data
print("Beginning Data Retrieval")
print("-----------------------------")


for index, row in weather_df.iterrows():
    
    city = row["City"]
    
    query_url = base_url + "appid=" + weather_api_key + "&q=" + city
    weather_response = requests.get(query_url).json()
 
    try:
        print(f"Processing Record {record}  of Set {sets} | {city}.")
        #print (query_url) 
        
        weather_df.loc[index, "Country"] = weather_response["sys"]["country"]     
        weather_df.loc[index, "Date"] = datetime.datetime.fromtimestamp(weather_response["dt"])
        weather_df.loc[index, "Latitude"] = weather_response["coord"]["lat"]
        weather_df.loc[index, "Longitude"] = weather_response["coord"]["lon"]
        weather_df.loc[index, "Cloudiness (%)"] = weather_response["clouds"]["all"]
        weather_df.loc[index, "Humidity (%)"] = weather_response["main"]["humidity"]
        weather_df.loc[index, "Max Temp (F)"] = 1.8 * (weather_response["main"]["temp_max"] - 273) + 32
        weather_df.loc[index, "Wind Speed (mph)"] = weather_response["wind"]["speed"]
               
    except:
        print(f"City not found...skipping {city}.")
        #print (query_url) 
        
    
    record = record + 1
    if record == 50:
        record = 0
        sets = sets + 1 

print("-----------------------------")        
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0  of Set 1 | punta arenas.
# City not found...skipping punta arenas.
# Processing Record 1  of Set 1 | bluff.
# City not found...skipping bluff.
# Processing Record 2  of Set 1 | sitka.
# City not found...skipping sitka.
# Processing Record 3  of Set 1 | rikitea.
# City not found...skipping rikitea.
# Processing Record 4  of Set 1 | butaritari.
# City not found...skipping butaritari.
# Processing Record 5  of Set 1 | sorland.
# City not found...skipping sorland.
# Processing Record 6  of Set 1 | ketchikan.
# City not found...skipping ketchikan.
# Processing Record 7  of Set 1 | ambilobe.
# City not found...skipping ambilobe.
# Processing Record 8  of Set 1 | severo-kurilsk.
# City not found...skipping severo-kurilsk.
# Processing Record 9  of Set 1 | port alfred.
# City not found...skipping port alfred.
# Processing Record 10  of Set 1 | cepu.
# City not found...skipping cepu.
# Processing Record 11  of Set 1 | avarua.
# City not found...skipping avarua.
# Processing Record 12  of Set 1 | tsihombe.
# City not found...skipping tsihombe.
# Processing Record 13  of Set 1 | esil.
# City not found...skipping esil.
# Processing Record 14  of Set 1 | truckee.
# City not found...skipping truckee.
# Processing Record 15  of Set 1 | east london.
# City not found...skipping east london.
# Processing Record 16  of Set 1 | iqaluit.
# City not found...skipping iqaluit.
# Processing Record 17  of Set 1 | dekoa.
# City not found...skipping dekoa.
# Processing Record 18  of Set 1 | taolanaro.
# City not found...skipping taolanaro.
# Processing Record 19  of Set 1 | hermanus.
# City not found...skipping hermanus.
# Processing Record 20  of Set 1 | nezhinka.
# City not found...skipping nezhinka.
# Processing Record 21  of Set 1 | yellowknife.
# City not found...skipping yellowknife.
# Processing Record 22  of Set 1 | clyde river.
# City not found...skipping clyde river.
# Processing Record 23  of Set 1 | lebu.
# City not found...skipping lebu.
# Processing Record 24  of Set 1 | bolungarvik.
# City not found...skipping bolungarvik.
# Processing Record 25  of Set 1 | avera.
# City not found...skipping avera.
# Processing Record 26  of Set 1 | honiara.
# City not found...skipping honiara.
# Processing Record 27  of Set 1 | sioux lookout.
# City not found...skipping sioux lookout.
# Processing Record 28  of Set 1 | bilibino.
# City not found...skipping bilibino.
# Processing Record 29  of Set 1 | nikolskoye.
# City not found...skipping nikolskoye.
# Processing Record 30  of Set 1 | yerbogachen.
# City not found...skipping yerbogachen.
# Processing Record 31  of Set 1 | faanui.
# City not found...skipping faanui.
# Processing Record 32  of Set 1 | riyadh.
# City not found...skipping riyadh.
# Processing Record 33  of Set 1 | hede.
# City not found...skipping hede.
# Processing Record 34  of Set 1 | hilo.
# City not found...skipping hilo.
# Processing Record 35  of Set 1 | busselton.
# City not found...skipping busselton.
# Processing Record 36  of Set 1 | puerto ayora.
# City not found...skipping puerto ayora.
# Processing Record 37  of Set 1 | svetlaya.
# City not found...skipping svetlaya.
# Processing Record 38  of Set 1 | omboue.
# City not found...skipping omboue.
# Processing Record 39  of Set 1 | kapaa.
# City not found...skipping kapaa.
# Processing Record 40  of Set 1 | price.
# City not found...skipping price.
# Processing Record 41  of Set 1 | vaini.
# City not found...skipping vaini.
# Processing Record 42  of Set 1 | ibirataia.
# City not found...skipping ibirataia.
# Processing Record 43  of Set 1 | lahaina.
# City not found...skipping lahaina.
# Processing Record 44  of Set 1 | cabo san lucas.
# City not found...skipping cabo san lucas.
# Processing Record 45  of Set 1 | mataura.
# City not found...skipping mataura.
# Processing Record 46  of Set 1 | pevek.
# City not found...skipping pevek.
# Processing Record 47  of Set 1 | ushuaia.
# City not found...skipping ushuaia.
# Processing Record 48  of Set 1 | carnarvon.
# City not found...skipping carnarvon.
# Processing Record 49  of Set 1 | yizheng.
# City not found...skipping yizheng.
# Processing Record 0  of Set 2 | mar del plata.
# City not found...skipping mar del plata.
# Processing Record 1  of Set 2 | vung tau.
# City not found...skipping vung tau.
# Processing Record 2  of Set 2 | isangel.
# City not found...skipping isangel.
# Processing Record 3  of Set 2 | hobart.
# City not found...skipping hobart.
# Processing Record 4  of Set 2 | mumford.
# City not found...skipping mumford.
# Processing Record 5  of Set 2 | tuktoyaktuk.
# City not found...skipping tuktoyaktuk.
# Processing Record 6  of Set 2 | pueblo nuevo.
# City not found...skipping pueblo nuevo.
# Processing Record 7  of Set 2 | sur.
# City not found...skipping sur.
# Processing Record 8  of Set 2 | sabha.
# City not found...skipping sabha.
# Processing Record 9  of Set 2 | kaitangata.
# City not found...skipping kaitangata.
# Processing Record 10  of Set 2 | upernavik.
# City not found...skipping upernavik.
# Processing Record 11  of Set 2 | tiksi.
# City not found...skipping tiksi.
# Processing Record 12  of Set 2 | yialos.
# City not found...skipping yialos.
# Processing Record 13  of Set 2 | sentyabrskiy.
# City not found...skipping sentyabrskiy.
# Processing Record 14  of Set 2 | castro.
# City not found...skipping castro.
# Processing Record 15  of Set 2 | chokurdakh.
# City not found...skipping chokurdakh.
# Processing Record 16  of Set 2 | bitam.
# City not found...skipping bitam.
# Processing Record 17  of Set 2 | broome.
# City not found...skipping broome.
# Processing Record 18  of Set 2 | saint-joseph.
# City not found...skipping saint-joseph.
# Processing Record 19  of Set 2 | narsaq.
# City not found...skipping narsaq.
# Processing Record 20  of Set 2 | codrington.
# City not found...skipping codrington.
# Processing Record 21  of Set 2 | brindisi.
# City not found...skipping brindisi.
# Processing Record 22  of Set 2 | vapnyarka.
# City not found...skipping vapnyarka.
# Processing Record 23  of Set 2 | stryn.
# City not found...skipping stryn.
# Processing Record 24  of Set 2 | anicuns.
# City not found...skipping anicuns.
# Processing Record 25  of Set 2 | lata.
# City not found...skipping lata.
# Processing Record 26  of Set 2 | ponta do sol.
# City not found...skipping ponta do sol.
# Processing Record 27  of Set 2 | bethel.
# City not found...skipping bethel.
# Processing Record 28  of Set 2 | nizhneyansk.
# City not found...skipping nizhneyansk.
# Processing Record 29  of Set 2 | la asuncion.
# City not found...skipping la asuncion.
# Processing Record 30  of Set 2 | belushya guba.
# City not found...skipping belushya guba.
# Processing Record 31  of Set 2 | chernyshevskiy.
# City not found...skipping chernyshevskiy.
# Processing Record 32  of Set 2 | kavieng.
# City not found...skipping kavieng.
# Processing Record 33  of Set 2 | coquimbo.
# City not found...skipping coquimbo.
# Processing Record 34  of Set 2 | lyskovo.
# City not found...skipping lyskovo.
# Processing Record 35  of Set 2 | babanusah.
# City not found...skipping babanusah.
# Processing Record 36  of Set 2 | werda.
# City not found...skipping werda.
# Processing Record 37  of Set 2 | yuxia.
# City not found...skipping yuxia.
# Processing Record 38  of Set 2 | hendersonville.
# City not found...skipping hendersonville.
# Processing Record 39  of Set 2 | amderma.
# City not found...skipping amderma.
# Processing Record 40  of Set 2 | poronaysk.
# City not found...skipping poronaysk.
# Processing Record 41  of Set 2 | andenes.
# City not found...skipping andenes.
# Processing Record 42  of Set 2 | meulaboh.
# City not found...skipping meulaboh.
# Processing Record 43  of Set 2 | seoul.
# City not found...skipping seoul.
# Processing Record 44  of Set 2 | preston.
# City not found...skipping preston.
# Processing Record 45  of Set 2 | nyzhni sirohozy.
# City not found...skipping nyzhni sirohozy.
# Processing Record 46  of Set 2 | saint-gabriel.
# City not found...skipping saint-gabriel.
# Processing Record 47  of Set 2 | ferrara.
# City not found...skipping ferrara.
# Processing Record 48  of Set 2 | longhua.
# City not found...skipping longhua.
# Processing Record 49  of Set 2 | port hueneme.
# City not found...skipping port hueneme.
# Processing Record 0  of Set 3 | marsh harbour.
# City not found...skipping marsh harbour.
# Processing Record 1  of Set 3 | fairbanks.
# City not found...skipping fairbanks.
# Processing Record 2  of Set 3 | vaitupu.
# City not found...skipping vaitupu.
# Processing Record 3  of Set 3 | bandarbeyla.
# City not found...skipping bandarbeyla.
# Processing Record 4  of Set 3 | qaanaaq.
# City not found...skipping qaanaaq.
# Processing Record 5  of Set 3 | provideniya.
# City not found...skipping provideniya.
# Processing Record 6  of Set 3 | saleaula.
# City not found...skipping saleaula.
# Processing Record 7  of Set 3 | ribeira grande.
# City not found...skipping ribeira grande.
# Processing Record 8  of Set 3 | longyearbyen.
# City not found...skipping longyearbyen.
# Processing Record 9  of Set 3 | attawapiskat.
# City not found...skipping attawapiskat.
# Processing Record 10  of Set 3 | ilulissat.
# City not found...skipping ilulissat.
# Processing Record 11  of Set 3 | gogrial.
# City not found...skipping gogrial.
# Processing Record 12  of Set 3 | leningradskiy.
# City not found...skipping leningradskiy.
# Processing Record 13  of Set 3 | mopipi.
# City not found...skipping mopipi.
# Processing Record 14  of Set 3 | shelburne.
# City not found...skipping shelburne.
# Processing Record 15  of Set 3 | te anau.
# City not found...skipping te anau.
# Processing Record 16  of Set 3 | charters towers.
# City not found...skipping charters towers.
# Processing Record 17  of Set 3 | saint-philippe.
# City not found...skipping saint-philippe.
# Processing Record 18  of Set 3 | ancud.
# City not found...skipping ancud.
# Processing Record 19  of Set 3 | bengkulu.
# City not found...skipping bengkulu.
# Processing Record 20  of Set 3 | kamenskoye.
# City not found...skipping kamenskoye.
# Processing Record 21  of Set 3 | pak phanang.
# City not found...skipping pak phanang.
# Processing Record 22  of Set 3 | thompson.
# City not found...skipping thompson.
# Processing Record 23  of Set 3 | qui nhon.
# City not found...skipping qui nhon.
# Processing Record 24  of Set 3 | atuona.
# City not found...skipping atuona.
# Processing Record 25  of Set 3 | bredasdorp.
# City not found...skipping bredasdorp.
# Processing Record 26  of Set 3 | mahebourg.
# City not found...skipping mahebourg.
# Processing Record 27  of Set 3 | techiman.
# City not found...skipping techiman.
# Processing Record 28  of Set 3 | vostok.
# City not found...skipping vostok.
# Processing Record 29  of Set 3 | cayenne.
# City not found...skipping cayenne.
# Processing Record 30  of Set 3 | collipulli.
# City not found...skipping collipulli.
# Processing Record 31  of Set 3 | namibe.
# City not found...skipping namibe.
# Processing Record 32  of Set 3 | matara.
# City not found...skipping matara.
# Processing Record 33  of Set 3 | nanortalik.
# City not found...skipping nanortalik.
# Processing Record 34  of Set 3 | avare.
# City not found...skipping avare.
# Processing Record 35  of Set 3 | saint-augustin.
# City not found...skipping saint-augustin.
# Processing Record 36  of Set 3 | bontang.
# City not found...skipping bontang.
# Processing Record 37  of Set 3 | ambovombe.
# City not found...skipping ambovombe.
# Processing Record 38  of Set 3 | bathsheba.
# City not found...skipping bathsheba.
# Processing Record 39  of Set 3 | steinbach.
# City not found...skipping steinbach.
# Processing Record 40  of Set 3 | arraial do cabo.
# City not found...skipping arraial do cabo.
# Processing Record 41  of Set 3 | tasiilaq.
# City not found...skipping tasiilaq.
# Processing Record 42  of Set 3 | lompoc.
# City not found...skipping lompoc.
# Processing Record 43  of Set 3 | coahuayana.
# City not found...skipping coahuayana.
# Processing Record 44  of Set 3 | seydi.
# City not found...skipping seydi.
# Processing Record 45  of Set 3 | aksha.
# City not found...skipping aksha.
# Processing Record 46  of Set 3 | pinawa.
# City not found...skipping pinawa.
# Processing Record 47  of Set 3 | coihaique.
# City not found...skipping coihaique.
# Processing Record 48  of Set 3 | skagastrond.
# City not found...skipping skagastrond.
# Processing Record 49  of Set 3 | palabuhanratu.
# City not found...skipping palabuhanratu.
# Processing Record 0  of Set 4 | bubaque.
# City not found...skipping bubaque.
# Processing Record 1  of Set 4 | hasaki.
# City not found...skipping hasaki.
# Processing Record 2  of Set 4 | jacareacanga.
# City not found...skipping jacareacanga.
# Processing Record 3  of Set 4 | cape town.
# City not found...skipping cape town.
# Processing Record 4  of Set 4 | kamenka.
# City not found...skipping kamenka.
# Processing Record 5  of Set 4 | albany.
# City not found...skipping albany.
# Processing Record 6  of Set 4 | denpasar.
# City not found...skipping denpasar.
# Processing Record 7  of Set 4 | karlshamn.
# City not found...skipping karlshamn.
# Processing Record 8  of Set 4 | shaowu.
# City not found...skipping shaowu.
# Processing Record 9  of Set 4 | luwuk.
# City not found...skipping luwuk.
# Processing Record 10  of Set 4 | buchanan.
# City not found...skipping buchanan.
# Processing Record 11  of Set 4 | saint andrews.
# City not found...skipping saint andrews.
# Processing Record 12  of Set 4 | katsuura.
# City not found...skipping katsuura.
# Processing Record 13  of Set 4 | kodiak.
# City not found...skipping kodiak.
# Processing Record 14  of Set 4 | henties bay.
# City not found...skipping henties bay.
# Processing Record 15  of Set 4 | merauke.
# City not found...skipping merauke.
# Processing Record 16  of Set 4 | kaardi.
# City not found...skipping kaardi.
# Processing Record 17  of Set 4 | newport.
# City not found...skipping newport.
# Processing Record 18  of Set 4 | makakilo city.
# City not found...skipping makakilo city.
# Processing Record 19  of Set 4 | parakou.
# City not found...skipping parakou.
# Processing Record 20  of Set 4 | kegayli.
# City not found...skipping kegayli.
# Processing Record 21  of Set 4 | saldanha.
# City not found...skipping saldanha.
# Processing Record 22  of Set 4 | anadyr.
# City not found...skipping anadyr.
# Processing Record 23  of Set 4 | sable-sur-sarthe.
# City not found...skipping sable-sur-sarthe.
# Processing Record 24  of Set 4 | esperance.
# City not found...skipping esperance.
# Processing Record 25  of Set 4 | khatanga.
# City not found...skipping khatanga.
# Processing Record 26  of Set 4 | ambon.
# City not found...skipping ambon.
# Processing Record 27  of Set 4 | maputo.
# City not found...skipping maputo.
# Processing Record 28  of Set 4 | nongstoin.
# City not found...skipping nongstoin.
# Processing Record 29  of Set 4 | poso.
# City not found...skipping poso.
# Processing Record 30  of Set 4 | salinopolis.
# City not found...skipping salinopolis.
# Processing Record 31  of Set 4 | yumen.
# City not found...skipping yumen.
# Processing Record 32  of Set 4 | klaksvik.
# City not found...skipping klaksvik.
# Processing Record 33  of Set 4 | baruun-urt.
# City not found...skipping baruun-urt.
# Processing Record 34  of Set 4 | lashio.
# City not found...skipping lashio.
# Processing Record 35  of Set 4 | vila do maio.
# City not found...skipping vila do maio.
# Processing Record 36  of Set 4 | nuuk.
# City not found...skipping nuuk.
# Processing Record 37  of Set 4 | evensk.
# City not found...skipping evensk.
# Processing Record 38  of Set 4 | husavik.
# City not found...skipping husavik.
# Processing Record 39  of Set 4 | mirnyy.
# City not found...skipping mirnyy.
# Processing Record 40  of Set 4 | necochea.
# City not found...skipping necochea.
# Processing Record 41  of Set 4 | adrar.
# City not found...skipping adrar.
# Processing Record 42  of Set 4 | yarmouth.
# City not found...skipping yarmouth.
# Processing Record 43  of Set 4 | rafaela.
# City not found...skipping rafaela.
# Processing Record 44  of Set 4 | georgetown.
# City not found...skipping georgetown.
# Processing Record 45  of Set 4 | belokurikha.
# City not found...skipping belokurikha.
# Processing Record 46  of Set 4 | sergeyevka.
# City not found...skipping sergeyevka.
# Processing Record 47  of Set 4 | andros town.
# City not found...skipping andros town.
# Processing Record 48  of Set 4 | morehead.
# City not found...skipping morehead.
# Processing Record 49  of Set 4 | barentsburg.
# City not found...skipping barentsburg.
# Processing Record 0  of Set 5 | turukhansk.
# City not found...skipping turukhansk.
# Processing Record 1  of Set 5 | saskylakh.
# City not found...skipping saskylakh.
# Processing Record 2  of Set 5 | tarudant.
# City not found...skipping tarudant.
# Processing Record 3  of Set 5 | watrous.
# City not found...skipping watrous.
# Processing Record 4  of Set 5 | constitucion.
# City not found...skipping constitucion.
# Processing Record 5  of Set 5 | praia.
# City not found...skipping praia.
# Processing Record 6  of Set 5 | buala.
# City not found...skipping buala.
# Processing Record 7  of Set 5 | solnechnyy.
# City not found...skipping solnechnyy.
# Processing Record 8  of Set 5 | alekseyevka.
# City not found...skipping alekseyevka.
# Processing Record 9  of Set 5 | mandera.
# City not found...skipping mandera.
# Processing Record 10  of Set 5 | nsanje.
# City not found...skipping nsanje.
# Processing Record 11  of Set 5 | plettenberg bay.
# City not found...skipping plettenberg bay.
# Processing Record 12  of Set 5 | mahanoro.
# City not found...skipping mahanoro.
# Processing Record 13  of Set 5 | yinchuan.
# City not found...skipping yinchuan.
# Processing Record 14  of Set 5 | padang.
# City not found...skipping padang.
# Processing Record 15  of Set 5 | nabire.
# City not found...skipping nabire.
# Processing Record 16  of Set 5 | gadwal.
# City not found...skipping gadwal.
# Processing Record 17  of Set 5 | richards bay.
# City not found...skipping richards bay.
# Processing Record 18  of Set 5 | yeppoon.
# City not found...skipping yeppoon.
# Processing Record 19  of Set 5 | dumas.
# City not found...skipping dumas.
# Processing Record 20  of Set 5 | los llanos de aridane.
# City not found...skipping los llanos de aridane.
# Processing Record 21  of Set 5 | vestmannaeyjar.
# City not found...skipping vestmannaeyjar.
# Processing Record 22  of Set 5 | teacapan.
# City not found...skipping teacapan.
# Processing Record 23  of Set 5 | mergui.
# City not found...skipping mergui.
# Processing Record 24  of Set 5 | maltahohe.
# City not found...skipping maltahohe.
# Processing Record 25  of Set 5 | jurm.
# City not found...skipping jurm.
# Processing Record 26  of Set 5 | cidreira.
# City not found...skipping cidreira.
# Processing Record 27  of Set 5 | marcona.
# City not found...skipping marcona.
# Processing Record 28  of Set 5 | san policarpo.
# City not found...skipping san policarpo.
# Processing Record 29  of Set 5 | chuy.
# City not found...skipping chuy.
# Processing Record 30  of Set 5 | pasighat.
# City not found...skipping pasighat.
# Processing Record 31  of Set 5 | geraldton.
# City not found...skipping geraldton.
# Processing Record 32  of Set 5 | tessalit.
# City not found...skipping tessalit.
# Processing Record 33  of Set 5 | illoqqortoormiut.
# City not found...skipping illoqqortoormiut.
# Processing Record 34  of Set 5 | torbay.
# City not found...skipping torbay.
# Processing Record 35  of Set 5 | westerly.
# City not found...skipping westerly.
# Processing Record 36  of Set 5 | itarema.
# City not found...skipping itarema.
# Processing Record 37  of Set 5 | salalah.
# City not found...skipping salalah.
# Processing Record 38  of Set 5 | airai.
# City not found...skipping airai.
# Processing Record 39  of Set 5 | pitimbu.
# City not found...skipping pitimbu.
# Processing Record 40  of Set 5 | dikson.
# City not found...skipping dikson.
# Processing Record 41  of Set 5 | burrel.
# City not found...skipping burrel.
# Processing Record 42  of Set 5 | diamantino.
# City not found...skipping diamantino.
# Processing Record 43  of Set 5 | bada.
# City not found...skipping bada.
# Processing Record 44  of Set 5 | sines.
# City not found...skipping sines.
# Processing Record 45  of Set 5 | barrow.
# City not found...skipping barrow.
# Processing Record 46  of Set 5 | funadhoo.
# City not found...skipping funadhoo.
# Processing Record 47  of Set 5 | verkhnyaya inta.
# City not found...skipping verkhnyaya inta.
# Processing Record 48  of Set 5 | palmer.
# City not found...skipping palmer.
# Processing Record 49  of Set 5 | dhidhdhoo.
# City not found...skipping dhidhdhoo.
# Processing Record 0  of Set 6 | lupsa.
# City not found...skipping lupsa.
# Processing Record 1  of Set 6 | christchurch.
# City not found...skipping christchurch.
# Processing Record 2  of Set 6 | bambous virieux.
# City not found...skipping bambous virieux.
# Processing Record 3  of Set 6 | tyler.
# City not found...skipping tyler.
# Processing Record 4  of Set 6 | saravan.
# City not found...skipping saravan.
# Processing Record 5  of Set 6 | westport.
# City not found...skipping westport.
# Processing Record 6  of Set 6 | caravelas.
# City not found...skipping caravelas.
# Processing Record 7  of Set 6 | puerto lempira.
# City not found...skipping puerto lempira.
# Processing Record 8  of Set 6 | aklavik.
# City not found...skipping aklavik.
# Processing Record 9  of Set 6 | huron.
# City not found...skipping huron.
# Processing Record 10  of Set 6 | alotau.
# City not found...skipping alotau.
# Processing Record 11  of Set 6 | jinchang.
# City not found...skipping jinchang.
# Processing Record 12  of Set 6 | jamestown.
# City not found...skipping jamestown.
# Processing Record 13  of Set 6 | sao filipe.
# City not found...skipping sao filipe.
# Processing Record 14  of Set 6 | fortuna.
# City not found...skipping fortuna.
# Processing Record 15  of Set 6 | kolpashevo.
# City not found...skipping kolpashevo.
# Processing Record 16  of Set 6 | new norfolk.
# City not found...skipping new norfolk.
# Processing Record 17  of Set 6 | grand river south east.
# City not found...skipping grand river south east.
# Processing Record 18  of Set 6 | atar.
# City not found...skipping atar.
# Processing Record 19  of Set 6 | rocha.
# City not found...skipping rocha.
# Processing Record 20  of Set 6 | naze.
# City not found...skipping naze.
# Processing Record 21  of Set 6 | yaan.
# City not found...skipping yaan.
# Processing Record 22  of Set 6 | ekhabi.
# City not found...skipping ekhabi.
# Processing Record 23  of Set 6 | kirovskiy.
# City not found...skipping kirovskiy.
# Processing Record 24  of Set 6 | lai.
# City not found...skipping lai.
# Processing Record 25  of Set 6 | vila velha.
# City not found...skipping vila velha.
# Processing Record 26  of Set 6 | kibara.
# City not found...skipping kibara.
# Processing Record 27  of Set 6 | lavrentiya.
# City not found...skipping lavrentiya.
# Processing Record 28  of Set 6 | port-gentil.
# City not found...skipping port-gentil.
# Processing Record 29  of Set 6 | podor.
# City not found...skipping podor.
# Processing Record 30  of Set 6 | kurush.
# City not found...skipping kurush.
# Processing Record 31  of Set 6 | muli.
# City not found...skipping muli.
# Processing Record 32  of Set 6 | nata.
# City not found...skipping nata.
# Processing Record 33  of Set 6 | olga.
# City not found...skipping olga.
# Processing Record 34  of Set 6 | komsomolskiy.
# City not found...skipping komsomolskiy.
# Processing Record 35  of Set 6 | kachiry.
# City not found...skipping kachiry.
# Processing Record 36  of Set 6 | ahuimanu.
# City not found...skipping ahuimanu.
# Processing Record 37  of Set 6 | luganville.
# City not found...skipping luganville.
# Processing Record 38  of Set 6 | mutata.
# City not found...skipping mutata.
# Processing Record 39  of Set 6 | ozu.
# City not found...skipping ozu.
# Processing Record 40  of Set 6 | sinjar.
# City not found...skipping sinjar.
# Processing Record 41  of Set 6 | russell.
# City not found...skipping russell.
# Processing Record 42  of Set 6 | pangai.
# City not found...skipping pangai.
# Processing Record 43  of Set 6 | novopokrovka.
# City not found...skipping novopokrovka.
# Processing Record 44  of Set 6 | ocos.
# City not found...skipping ocos.
# Processing Record 45  of Set 6 | kozhva.
# City not found...skipping kozhva.
# Processing Record 46  of Set 6 | qobustan.
# City not found...skipping qobustan.
# Processing Record 47  of Set 6 | lumphat.
# City not found...skipping lumphat.
# Processing Record 48  of Set 6 | san patricio.
# City not found...skipping san patricio.
# Processing Record 49  of Set 6 | touros.
# City not found...skipping touros.
# Processing Record 0  of Set 7 | helong.
# City not found...skipping helong.
# Processing Record 1  of Set 7 | nome.
# City not found...skipping nome.
# Processing Record 2  of Set 7 | nizhniy novgorod.
# City not found...skipping nizhniy novgorod.
# Processing Record 3  of Set 7 | mizan teferi.
# City not found...skipping mizan teferi.
# Processing Record 4  of Set 7 | tabou.
# City not found...skipping tabou.
# Processing Record 5  of Set 7 | langsa.
# City not found...skipping langsa.
# Processing Record 6  of Set 7 | road town.
# City not found...skipping road town.
# Processing Record 7  of Set 7 | najran.
# City not found...skipping najran.
# Processing Record 8  of Set 7 | tilichiki.
# City not found...skipping tilichiki.
# Processing Record 9  of Set 7 | takaka.
# City not found...skipping takaka.
# Processing Record 10  of Set 7 | quatre cocos.
# City not found...skipping quatre cocos.
# Processing Record 11  of Set 7 | zhuhai.
# City not found...skipping zhuhai.
# Processing Record 12  of Set 7 | ziro.
# City not found...skipping ziro.
# Processing Record 13  of Set 7 | hrubieszow.
# City not found...skipping hrubieszow.
# Processing Record 14  of Set 7 | senekal.
# City not found...skipping senekal.
# Processing Record 15  of Set 7 | kampot.
# City not found...skipping kampot.
# Processing Record 16  of Set 7 | leopold.
# City not found...skipping leopold.
# Processing Record 17  of Set 7 | bandar.
# City not found...skipping bandar.
# Processing Record 18  of Set 7 | shenjiamen.
# City not found...skipping shenjiamen.
# Processing Record 19  of Set 7 | asfi.
# City not found...skipping asfi.
# Processing Record 20  of Set 7 | saint george.
# City not found...skipping saint george.
# Processing Record 21  of Set 7 | sartana.
# City not found...skipping sartana.
# Processing Record 22  of Set 7 | mandalgovi.
# City not found...skipping mandalgovi.
# Processing Record 23  of Set 7 | socorro.
# City not found...skipping socorro.
# Processing Record 24  of Set 7 | dukat.
# City not found...skipping dukat.
# Processing Record 25  of Set 7 | egvekinot.
# City not found...skipping egvekinot.
# Processing Record 26  of Set 7 | camenca.
# City not found...skipping camenca.
# Processing Record 27  of Set 7 | faya.
# City not found...skipping faya.
# Processing Record 28  of Set 7 | chagda.
# City not found...skipping chagda.
# Processing Record 29  of Set 7 | high level.
# City not found...skipping high level.
# Processing Record 30  of Set 7 | lazaro cardenas.
# City not found...skipping lazaro cardenas.
# Processing Record 31  of Set 7 | ihosy.
# City not found...skipping ihosy.
# Processing Record 32  of Set 7 | abu samrah.
# City not found...skipping abu samrah.
# Processing Record 33  of Set 7 | soskovo.
# City not found...skipping soskovo.
# Processing Record 34  of Set 7 | pandan.
# City not found...skipping pandan.
# Processing Record 35  of Set 7 | garowe.
# City not found...skipping garowe.
# Processing Record 36  of Set 7 | umzimvubu.
# City not found...skipping umzimvubu.
# Processing Record 37  of Set 7 | yarim.
# City not found...skipping yarim.
# Processing Record 38  of Set 7 | russellville.
# City not found...skipping russellville.
# Processing Record 39  of Set 7 | dubbo.
# City not found...skipping dubbo.
# Processing Record 40  of Set 7 | dovers.
# City not found...skipping dovers.
# Processing Record 41  of Set 7 | kazalinsk.
# City not found...skipping kazalinsk.
# Processing Record 42  of Set 7 | mbigou.
# City not found...skipping mbigou.
# Processing Record 43  of Set 7 | vila franca do campo.
# City not found...skipping vila franca do campo.
# Processing Record 44  of Set 7 | the valley.
# City not found...skipping the valley.
# Processing Record 45  of Set 7 | hobyo.
# City not found...skipping hobyo.
# Processing Record 46  of Set 7 | la ronge.
# City not found...skipping la ronge.
# Processing Record 47  of Set 7 | xiangdong.
# City not found...skipping xiangdong.
# Processing Record 48  of Set 7 | joshimath.
# City not found...skipping joshimath.
# Processing Record 49  of Set 7 | baiyin.
# City not found...skipping baiyin.
# Processing Record 0  of Set 8 | sarkeresztur.
# City not found...skipping sarkeresztur.
# Processing Record 1  of Set 8 | dubti.
# City not found...skipping dubti.
# Processing Record 2  of Set 8 | paamiut.
# City not found...skipping paamiut.
# Processing Record 3  of Set 8 | inuvik.
# City not found...skipping inuvik.
# Processing Record 4  of Set 8 | rawson.
# City not found...skipping rawson.
# Processing Record 5  of Set 8 | da nang.
# City not found...skipping da nang.
# Processing Record 6  of Set 8 | athabasca.
# City not found...skipping athabasca.
# Processing Record 7  of Set 8 | tari.
# City not found...skipping tari.
# Processing Record 8  of Set 8 | ngukurr.
# City not found...skipping ngukurr.
# Processing Record 9  of Set 8 | zhigansk.
# City not found...skipping zhigansk.
# Processing Record 10  of Set 8 | ilheus.
# City not found...skipping ilheus.
# Processing Record 11  of Set 8 | nuevo mexico.
# City not found...skipping nuevo mexico.
# Processing Record 12  of Set 8 | ostrovnoy.
# City not found...skipping ostrovnoy.
# Processing Record 13  of Set 8 | lingao.
# City not found...skipping lingao.
# Processing Record 14  of Set 8 | spirit river.
# City not found...skipping spirit river.
# Processing Record 15  of Set 8 | port macquarie.
# City not found...skipping port macquarie.
# Processing Record 16  of Set 8 | dedovichi.
# City not found...skipping dedovichi.
# Processing Record 17  of Set 8 | hamilton.
# City not found...skipping hamilton.
# Processing Record 18  of Set 8 | kununurra.
# City not found...skipping kununurra.
# Processing Record 19  of Set 8 | pisco.
# City not found...skipping pisco.
# Processing Record 20  of Set 8 | samalaeulu.
# City not found...skipping samalaeulu.
# Processing Record 21  of Set 8 | jaromer.
# City not found...skipping jaromer.
# Processing Record 22  of Set 8 | cukai.
# City not found...skipping cukai.
# Processing Record 23  of Set 8 | burkhala.
# City not found...skipping burkhala.
# Processing Record 24  of Set 8 | cutro.
# City not found...skipping cutro.
# Processing Record 25  of Set 8 | bargal.
# City not found...skipping bargal.
# Processing Record 26  of Set 8 | taltal.
# City not found...skipping taltal.
# Processing Record 27  of Set 8 | kuopio.
# City not found...skipping kuopio.
# Processing Record 28  of Set 8 | griffith.
# City not found...skipping griffith.
# Processing Record 29  of Set 8 | uran.
# City not found...skipping uran.
# Processing Record 30  of Set 8 | cody.
# City not found...skipping cody.
# Processing Record 31  of Set 8 | grand centre.
# City not found...skipping grand centre.
# Processing Record 32  of Set 8 | west bay.
# City not found...skipping west bay.
# Processing Record 33  of Set 8 | cherskiy.
# City not found...skipping cherskiy.
# Processing Record 34  of Set 8 | santa rosalia.
# City not found...skipping santa rosalia.
# Processing Record 35  of Set 8 | guerrero negro.
# City not found...skipping guerrero negro.
# Processing Record 36  of Set 8 | vardo.
# City not found...skipping vardo.
# Processing Record 37  of Set 8 | batagay.
# City not found...skipping batagay.
# Processing Record 38  of Set 8 | samarai.
# City not found...skipping samarai.
# Processing Record 39  of Set 8 | provost.
# City not found...skipping provost.
# Processing Record 40  of Set 8 | malakal.
# City not found...skipping malakal.
# Processing Record 41  of Set 8 | maridi.
# City not found...skipping maridi.
# Processing Record 42  of Set 8 | hays.
# City not found...skipping hays.
# Processing Record 43  of Set 8 | saint-honore.
# City not found...skipping saint-honore.
# Processing Record 44  of Set 8 | xinzhou.
# City not found...skipping xinzhou.
# Processing Record 45  of Set 8 | chapais.
# City not found...skipping chapais.
# Processing Record 46  of Set 8 | gold coast.
# City not found...skipping gold coast.
# Processing Record 47  of Set 8 | port lincoln.
# City not found...skipping port lincoln.
# Processing Record 48  of Set 8 | gorontalo.
# City not found...skipping gorontalo.
# Processing Record 49  of Set 8 | ndola.
# City not found...skipping ndola.
# Processing Record 0  of Set 9 | lakes entrance.
# City not found...skipping lakes entrance.
# Processing Record 1  of Set 9 | portland.
# City not found...skipping portland.
# Processing Record 2  of Set 9 | sechura.
# City not found...skipping sechura.
# Processing Record 3  of Set 9 | wasilla.
# City not found...skipping wasilla.
# Processing Record 4  of Set 9 | verin.
# City not found...skipping verin.
# Processing Record 5  of Set 9 | victoria.
# City not found...skipping victoria.
# Processing Record 6  of Set 9 | smoky lake.
# City not found...skipping smoky lake.
# Processing Record 7  of Set 9 | college.
# City not found...skipping college.
# Processing Record 8  of Set 9 | haileybury.
# City not found...skipping haileybury.
# Processing Record 9  of Set 9 | mys shmidta.
# City not found...skipping mys shmidta.
# Processing Record 10  of Set 9 | verkhnevilyuysk.
# City not found...skipping verkhnevilyuysk.
# Processing Record 11  of Set 9 | carutapera.
# City not found...skipping carutapera.
# Processing Record 12  of Set 9 | altay.
# City not found...skipping altay.
# Processing Record 13  of Set 9 | haapsalu.
# City not found...skipping haapsalu.
# Processing Record 14  of Set 9 | manono.
# City not found...skipping manono.
# Processing Record 15  of Set 9 | tadine.
# City not found...skipping tadine.
# Processing Record 16  of Set 9 | bayanday.
# City not found...skipping bayanday.
# Processing Record 17  of Set 9 | ubinskoye.
# City not found...skipping ubinskoye.
# Processing Record 18  of Set 9 | townsville.
# City not found...skipping townsville.
# Processing Record 19  of Set 9 | hithadhoo.
# City not found...skipping hithadhoo.
# Processing Record 20  of Set 9 | port elizabeth.
# City not found...skipping port elizabeth.
# Processing Record 21  of Set 9 | hambantota.
# City not found...skipping hambantota.
# Processing Record 22  of Set 9 | mangrol.
# City not found...skipping mangrol.
# Processing Record 23  of Set 9 | alyangula.
# City not found...skipping alyangula.
# Processing Record 24  of Set 9 | sibolga.
# City not found...skipping sibolga.
# Processing Record 25  of Set 9 | bar harbor.
# City not found...skipping bar harbor.
# Processing Record 26  of Set 9 | hauterive.
# City not found...skipping hauterive.
# Processing Record 27  of Set 9 | kazerun.
# City not found...skipping kazerun.
# Processing Record 28  of Set 9 | maralal.
# City not found...skipping maralal.
# Processing Record 29  of Set 9 | petropavlovsk-kamchatskiy.
# City not found...skipping petropavlovsk-kamchatskiy.
# Processing Record 30  of Set 9 | nouadhibou.
# City not found...skipping nouadhibou.
# Processing Record 31  of Set 9 | casper.
# City not found...skipping casper.
# Processing Record 32  of Set 9 | diyarb najm.
# City not found...skipping diyarb najm.
# Processing Record 33  of Set 9 | kontagora.
# City not found...skipping kontagora.
# Processing Record 34  of Set 9 | luan.
# City not found...skipping luan.
# Processing Record 35  of Set 9 | teya.
# City not found...skipping teya.
# Processing Record 36  of Set 9 | aketi.
# City not found...skipping aketi.
# Processing Record 37  of Set 9 | louisbourg.
# City not found...skipping louisbourg.
# Processing Record 38  of Set 9 | sobolevo.
# City not found...skipping sobolevo.
# Processing Record 39  of Set 9 | novorudnyy.
# City not found...skipping novorudnyy.
# Processing Record 40  of Set 9 | zaysan.
# City not found...skipping zaysan.
# Processing Record 41  of Set 9 | kayerkan.
# City not found...skipping kayerkan.
# Processing Record 42  of Set 9 | souillac.
# City not found...skipping souillac.
# Processing Record 43  of Set 9 | lagoa.
# City not found...skipping lagoa.
# Processing Record 44  of Set 9 | chase.
# City not found...skipping chase.
# Processing Record 45  of Set 9 | warqla.
# City not found...skipping warqla.
# Processing Record 46  of Set 9 | comodoro rivadavia.
# City not found...skipping comodoro rivadavia.
# Processing Record 47  of Set 9 | cravo norte.
# City not found...skipping cravo norte.
# Processing Record 48  of Set 9 | alcudia.
# City not found...skipping alcudia.
# Processing Record 49  of Set 9 | pangnirtung.
# City not found...skipping pangnirtung.
# Processing Record 0  of Set 10 | mabaruma.
# City not found...skipping mabaruma.
# Processing Record 1  of Set 10 | labuhan.
# City not found...skipping labuhan.
# Processing Record 2  of Set 10 | kysyl-syr.
# City not found...skipping kysyl-syr.
# Processing Record 3  of Set 10 | panubigan.
# City not found...skipping panubigan.
# Processing Record 4  of Set 10 | micco.
# City not found...skipping micco.
# Processing Record 5  of Set 10 | dosso.
# City not found...skipping dosso.
# Processing Record 6  of Set 10 | matagami.
# City not found...skipping matagami.
# Processing Record 7  of Set 10 | vizinga.
# City not found...skipping vizinga.
# Processing Record 8  of Set 10 | kissamos.
# City not found...skipping kissamos.
# Processing Record 9  of Set 10 | navlya.
# City not found...skipping navlya.
# Processing Record 10  of Set 10 | yarada.
# City not found...skipping yarada.
# Processing Record 11  of Set 10 | novyy urgal.
# City not found...skipping novyy urgal.
# Processing Record 12  of Set 10 | moose factory.
# City not found...skipping moose factory.
# Processing Record 13  of Set 10 | san cristobal.
# City not found...skipping san cristobal.
# Processing Record 14  of Set 10 | udachnyy.
# City not found...skipping udachnyy.
# Processing Record 15  of Set 10 | dicabisagan.
# City not found...skipping dicabisagan.
# Processing Record 16  of Set 10 | sheregesh.
# City not found...skipping sheregesh.
# Processing Record 17  of Set 10 | eyl.
# City not found...skipping eyl.
# Processing Record 18  of Set 10 | vallenar.
# City not found...skipping vallenar.
# Processing Record 19  of Set 10 | dingle.
# City not found...skipping dingle.
# Processing Record 20  of Set 10 | khartoum.
# City not found...skipping khartoum.
# Processing Record 21  of Set 10 | gryazovets.
# City not found...skipping gryazovets.
# Processing Record 22  of Set 10 | coos bay.
# City not found...skipping coos bay.
# Processing Record 23  of Set 10 | orlandia.
# City not found...skipping orlandia.
# Processing Record 24  of Set 10 | mount isa.
# City not found...skipping mount isa.
# Processing Record 25  of Set 10 | viedma.
# City not found...skipping viedma.
# Processing Record 26  of Set 10 | batetskiy.
# City not found...skipping batetskiy.
# Processing Record 27  of Set 10 | vanimo.
# City not found...skipping vanimo.
# Processing Record 28  of Set 10 | pacific grove.
# City not found...skipping pacific grove.
# Processing Record 29  of Set 10 | namatanai.
# City not found...skipping namatanai.
# Processing Record 30  of Set 10 | mayumba.
# City not found...skipping mayumba.
# Processing Record 31  of Set 10 | hofn.
# City not found...skipping hofn.
# Processing Record 32  of Set 10 | half moon bay.
# City not found...skipping half moon bay.
# Processing Record 33  of Set 10 | sokoto.
# City not found...skipping sokoto.
# Processing Record 34  of Set 10 | norman wells.
# City not found...skipping norman wells.
# Processing Record 35  of Set 10 | skalistyy.
# City not found...skipping skalistyy.
# Processing Record 36  of Set 10 | bilma.
# City not found...skipping bilma.
# Processing Record 37  of Set 10 | tecoanapa.
# City not found...skipping tecoanapa.
# Processing Record 38  of Set 10 | lorengau.
# City not found...skipping lorengau.
# Processing Record 39  of Set 10 | manta.
# City not found...skipping manta.
# Processing Record 40  of Set 10 | la rioja.
# City not found...skipping la rioja.
# Processing Record 41  of Set 10 | palkino.
# City not found...skipping palkino.
# Processing Record 42  of Set 10 | vestmanna.
# City not found...skipping vestmanna.
# Processing Record 43  of Set 10 | rungata.
# City not found...skipping rungata.
# Processing Record 44  of Set 10 | sorvag.
# City not found...skipping sorvag.
# Processing Record 45  of Set 10 | farmersville.
# City not found...skipping farmersville.
# Processing Record 46  of Set 10 | shahr-e babak.
# City not found...skipping shahr-e babak.
# Processing Record 47  of Set 10 | meyungs.
# City not found...skipping meyungs.
# Processing Record 48  of Set 10 | kyshtovka.
# City not found...skipping kyshtovka.
# Processing Record 49  of Set 10 | dolbeau.
# City not found...skipping dolbeau.
# Processing Record 0  of Set 11 | rondonopolis.
# City not found...skipping rondonopolis.
# Processing Record 1  of Set 11 | grants.
# City not found...skipping grants.
# Processing Record 2  of Set 11 | saint marys.
# City not found...skipping saint marys.
# Processing Record 3  of Set 11 | durban.
# City not found...skipping durban.
# Processing Record 4  of Set 11 | sola.
# City not found...skipping sola.
# Processing Record 5  of Set 11 | poum.
# City not found...skipping poum.
# Processing Record 6  of Set 11 | salekhard.
# City not found...skipping salekhard.
# Processing Record 7  of Set 11 | laguna de duero.
# City not found...skipping laguna de duero.
# Processing Record 8  of Set 11 | samusu.
# City not found...skipping samusu.
# Processing Record 9  of Set 11 | ahipara.
# City not found...skipping ahipara.
# Processing Record 10  of Set 11 | muroto.
# City not found...skipping muroto.
# Processing Record 11  of Set 11 | bolshoye sorokino.
# City not found...skipping bolshoye sorokino.
# Processing Record 12  of Set 11 | mayo.
# City not found...skipping mayo.
# Processing Record 13  of Set 11 | grindavik.
# City not found...skipping grindavik.
# Processing Record 14  of Set 11 | katherine.
# City not found...skipping katherine.
# Processing Record 15  of Set 11 | soma.
# City not found...skipping soma.
# Processing Record 16  of Set 11 | ambulu.
# City not found...skipping ambulu.
# Processing Record 17  of Set 11 | inhambane.
# City not found...skipping inhambane.
# Processing Record 18  of Set 11 | hornepayne.
# City not found...skipping hornepayne.
# Processing Record 19  of Set 11 | kourou.
# City not found...skipping kourou.
# Processing Record 20  of Set 11 | tevriz.
# City not found...skipping tevriz.
# Processing Record 21  of Set 11 | kuito.
# City not found...skipping kuito.
# Processing Record 22  of Set 11 | beroroha.
# City not found...skipping beroroha.
# Processing Record 23  of Set 11 | port blair.
# City not found...skipping port blair.
# Processing Record 24  of Set 11 | miyoshi.
# City not found...skipping miyoshi.
# Processing Record 25  of Set 11 | isla mujeres.
# City not found...skipping isla mujeres.
# Processing Record 26  of Set 11 | hollins.
# City not found...skipping hollins.
# Processing Record 27  of Set 11 | ulladulla.
# City not found...skipping ulladulla.
# Processing Record 28  of Set 11 | zlitan.
# City not found...skipping zlitan.
# Processing Record 29  of Set 11 | srednekolymsk.
# City not found...skipping srednekolymsk.
# Processing Record 30  of Set 11 | pietersburg.
# City not found...skipping pietersburg.
# Processing Record 31  of Set 11 | verkhnyaya toyma.
# City not found...skipping verkhnyaya toyma.
# Processing Record 32  of Set 11 | mareeba.
# City not found...skipping mareeba.
# Processing Record 33  of Set 11 | nauta.
# City not found...skipping nauta.
# Processing Record 34  of Set 11 | talnakh.
# City not found...skipping talnakh.
# Processing Record 35  of Set 11 | big rapids.
# City not found...skipping big rapids.
# Processing Record 36  of Set 11 | olavarria.
# City not found...skipping olavarria.
# Processing Record 37  of Set 11 | trairi.
# City not found...skipping trairi.
# Processing Record 38  of Set 11 | harindanga.
# City not found...skipping harindanga.
# Processing Record 39  of Set 11 | arona.
# City not found...skipping arona.
# Processing Record 40  of Set 11 | vieques.
# City not found...skipping vieques.
# Processing Record 41  of Set 11 | ust-nera.
# City not found...skipping ust-nera.
# Processing Record 42  of Set 11 | xapuri.
# City not found...skipping xapuri.
# Processing Record 43  of Set 11 | klyuchi.
# City not found...skipping klyuchi.
# Processing Record 44  of Set 11 | todos santos.
# City not found...skipping todos santos.
# Processing Record 45  of Set 11 | aden.
# City not found...skipping aden.
# Processing Record 46  of Set 11 | asau.
# City not found...skipping asau.
# Processing Record 47  of Set 11 | sisimiut.
# City not found...skipping sisimiut.
# Processing Record 48  of Set 11 | vargashi.
# City not found...skipping vargashi.
# Processing Record 49  of Set 11 | finschhafen.
# City not found...skipping finschhafen.
# Processing Record 0  of Set 12 | marmaron.
# City not found...skipping marmaron.
# Processing Record 1  of Set 12 | conakry.
# City not found...skipping conakry.
# Processing Record 2  of Set 12 | oranjemund.
# City not found...skipping oranjemund.
# Processing Record 3  of Set 12 | wadi musa.
# City not found...skipping wadi musa.
# Processing Record 4  of Set 12 | tukrah.
# City not found...skipping tukrah.
# Processing Record 5  of Set 12 | baherden.
# City not found...skipping baherden.
# Processing Record 6  of Set 12 | george.
# City not found...skipping george.
# Processing Record 7  of Set 12 | jidong.
# City not found...skipping jidong.
# Processing Record 8  of Set 12 | port hardy.
# City not found...skipping port hardy.
# Processing Record 9  of Set 12 | kodinsk.
# City not found...skipping kodinsk.
# Processing Record 10  of Set 12 | tanete.
# City not found...skipping tanete.
# Processing Record 11  of Set 12 | tura.
# City not found...skipping tura.
# Processing Record 12  of Set 12 | itoman.
# City not found...skipping itoman.
# Processing Record 13  of Set 12 | urengoy.
# City not found...skipping urengoy.
# Processing Record 14  of Set 12 | bell ville.
# City not found...skipping bell ville.
# Processing Record 15  of Set 12 | eureka.
# City not found...skipping eureka.
# Processing Record 16  of Set 12 | gornopravdinsk.
# City not found...skipping gornopravdinsk.
# Processing Record 17  of Set 12 | kaputa.
# City not found...skipping kaputa.
# Processing Record 18  of Set 12 | alofi.
# City not found...skipping alofi.
# Processing Record 19  of Set 12 | qasigiannguit.
# City not found...skipping qasigiannguit.
# Processing Record 20  of Set 12 | yanam.
# City not found...skipping yanam.
# Processing Record 21  of Set 12 | novoagansk.
# City not found...skipping novoagansk.
# Processing Record 22  of Set 12 | mitu.
# City not found...skipping mitu.
# Processing Record 23  of Set 12 | flin flon.
# City not found...skipping flin flon.
# Processing Record 24  of Set 12 | roald.
# City not found...skipping roald.
# Processing Record 25  of Set 12 | benton harbor.
# City not found...skipping benton harbor.
# Processing Record 26  of Set 12 | tumannyy.
# City not found...skipping tumannyy.
# Processing Record 27  of Set 12 | kahului.
# City not found...skipping kahului.
# Processing Record 28  of Set 12 | porto nacional.
# City not found...skipping porto nacional.
# Processing Record 29  of Set 12 | nemuro.
# City not found...skipping nemuro.
# Processing Record 30  of Set 12 | maniitsoq.
# City not found...skipping maniitsoq.
# Processing Record 31  of Set 12 | pachino.
# City not found...skipping pachino.
# Processing Record 32  of Set 12 | gulshat.
# City not found...skipping gulshat.
# Processing Record 33  of Set 12 | borujerd.
# City not found...skipping borujerd.
# Processing Record 34  of Set 12 | vagur.
# City not found...skipping vagur.
# Processing Record 35  of Set 12 | belyy yar.
# City not found...skipping belyy yar.
# Processing Record 36  of Set 12 | adzope.
# City not found...skipping adzope.
# Processing Record 37  of Set 12 | canico.
# City not found...skipping canico.
# Processing Record 38  of Set 12 | sombrio.
# City not found...skipping sombrio.
# Processing Record 39  of Set 12 | arman.
# City not found...skipping arman.
# Processing Record 40  of Set 12 | betafo.
# City not found...skipping betafo.
# Processing Record 41  of Set 12 | nizwa.
# City not found...skipping nizwa.
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Data Count

weather_df.count()
# Out:
# City                592
# Country             592
# Date                592
# Latitude            592
# Longitude           592
# Cloudiness (%)      592
# Humidity (%)        592
# Max Temp (F)        592
# Wind Speed (mph)    592
# dtype: int64

# %%
# Convert data strings to float
pd.to_numeric(weather_df["Cloudiness (%)"]).astype(float)
pd.to_numeric(weather_df["Humidity (%)"]).astype(float)
pd.to_numeric(weather_df["Latitude"]).astype(float)
pd.to_numeric(weather_df["Longitude"]).astype(float)
pd.to_numeric(weather_df["Max Temp (F)"]).astype(float)
pd.to_numeric(weather_df["Wind Speed (mph)"]).astype(float)
weather_df

#Export DataFrame to CSV File
weather_df.to_csv("weather_df.csv")

# %%
# Display DataFrame
weather_df.head()
# Out:
#            City Country Date Latitude Longitude Cloudiness (%) Humidity (%)  \
# 0  punta arenas      CL
# 1         bluff      NZ
# 2         sitka      US
# 3       rikitea      PF
# 4    butaritari      KI
#
#   Max Temp (F) Wind Speed (mph)
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
remaining_cities = weather_df.loc[weather_df["City"] != "Failed!!!"]

remaining_cities
# Out:
#              City Country Date Latitude Longitude Cloudiness (%) Humidity (%)  \
# 0    punta arenas      CL
# 1           bluff      NZ
# 2           sitka      US
# 3         rikitea      PF
# 4      butaritari      KI
# ..            ...     ...  ...      ...       ...            ...          ...
# 587        canico      PT
# 588       sombrio      BR
# 589         arman      RU
# 590        betafo      MG
# 591         nizwa      OM
#
#     Max Temp (F) Wind Speed (mph)
# 0
# 1
# 2
# 3
# 4
# ..           ...              ...
# 587
# 588
# 589
# 590
# 591
#
# [592 rows x 9 columns]

# %%
test_stats = remaining_cities["Humidity (%)"].describe(include = "all")
print("The maximum humidity value is 100%, so there are no values greater than 100% in our data!")
#remaining_cities["Humidity(%)""].value_counts()
test_stats
# Out:
# The maximum humidity value is 100%, so there are no values greater than 100% in our data!
# count     592
# unique      1
# top
# freq      592
# Name: Humidity (%), dtype: object

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Max Temp (F)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.title(f"City Latitude vs Max Temperature ({today})")
print("The plot proves that as we generally move away from the equator, temperature drops")
# Out:
# The plot proves that as we generally move away from the equator, temperature drops

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Humidity (%)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title(f"City Latitude vs Humidity (%) ({today})")
print("The plot shows that there is no real pattern that can describe the relationship between latitude and humidity")
# Out:
# The plot shows that there is no real pattern that can describe the relationship between latitude and humidity

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Cloudiness (%)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title(f"City Latitude vs Cloudiness ({today})")
print("The plot shows that there is no real pattern that can describe the relationship between latitude and cloudiness")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
today = time.strftime("%m/%d/%Y")
plt.scatter(pd.to_numeric(weather_df["Latitude"]).astype(float), pd.to_numeric(weather_df["Wind Speed (mph)"]).astype(float), facecolors="blue", edgecolors="black", alpha = 0.5)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.title(f"City Latitude vs Wind Speed ({today})")
print("The plot shows that there is no real pattern that can describe the relationship between latitude and windspeed")

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
# Create Northern and Southern Hemisphere DataFrames
northern_df = weather_df.loc[pd.to_numeric(weather_df["Latitude"]).astype(float) > 0, :]
southern_df = weather_df.loc[pd.to_numeric(weather_df["Latitude"]).astype(float) < 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Max Temp (F)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a negative correlation.")
print("In the nothern hemisphere, as you move away from the equator the temperature decreases.")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Max Temp (F)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a positive correlation.")
print("In the southern hemisphere, as you get closer to the equator the temperature increases.")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Humidity (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.") 
plt.show()
Regression li

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Humidity (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Cloudiness (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Cloudiness (%)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Latitude']).astype(float)
y_values = pd.to_numeric(northern_df['Wind Speed (mph)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Latitude']).astype(float)
y_values = pd.to_numeric(southern_df['Wind Speed (mph)']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression does not display much of a correlation between the data sets.")
plt.show()
